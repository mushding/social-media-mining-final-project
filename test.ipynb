# %%
import requests

def fetch(url):
    response = requests.get(url)
    response = requests.get(url, cookies={'over18': '1'})  # 一直向 server 回答滿 18 歲了 !
    return response

url = 'https://www.ptt.cc/bbs/Gossiping/index.html'
resp = fetch(url)  # step-1

print(resp.text) # result of setp-1
# Out:
# <!DOCTYPE html>
# <html>
# 	<head>
# 		<meta charset="utf-8">
#
#
# <meta name="viewport" content="width=device-width, initial-scale=1">
#
# <title>看板 Gossiping 文章列表 - 批踢踢實業坊</title>
#
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/bbs-common.css">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/bbs-base.css" media="screen">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/bbs-custom.css">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/pushstream.css" media="screen">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/bbs-print.css" media="print">
#
#
#
#
# 	</head>
#     <body>
#
# <div id="topbar-container">
# 	<div id="topbar" class="bbs-content">
# 		<a id="logo" href="/bbs/">批踢踢實業坊</a>
# 		<span>&rsaquo;</span>
# 		<a class="board" href="/bbs/Gossiping/index.html"><span class="board-label">看板 </span>Gossiping</a>
# 		<a class="right small" href="/about.html">關於我們</a>
# 		<a class="right small" href="/contact.html">聯絡資訊</a>
# 	</div>
# </div>
#
# <div id="main-container">
# 	<div id="action-bar-container">
# 		<div class="action-bar">
# 			<div class="btn-group btn-group-dir">
# 				<a class="btn selected" href="/bbs/Gossiping/index.html">看板</a>
# 				<a class="btn" href="/man/Gossiping/index.html">精華區</a>
# 			</div>
# 			<div class="btn-group btn-group-paging">
# 				<a class="btn wide" href="/bbs/Gossiping/index1.html">最舊</a>
# 				<a class="btn wide" href="/bbs/Gossiping/index39133.html">&lsaquo; 上頁</a>
# 				<a class="btn wide disabled">下頁 &rsaquo;</a>
# 				<a class="btn wide" href="/bbs/Gossiping/index.html">最新</a>
# 			</div>
# 		</div>
# 	</div>
#
# 	<div class="r-list-container action-bar-margin bbs-screen">
# 		<div class="search-bar">
# 			<form type="get" action="search" id="search-bar">
# 				<input class="query" type="text" name="q" value="" placeholder="搜尋文章&#x22ef;">
# 			</form>
# 		</div>
#
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"></div>
# 			<div class="title">
#
# 				<a href="/bbs/Gossiping/M.1646815707.A.0DD.html">[問卦] 自己翻新電池很毒嗎？</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="author">nekokick</div>
# 				<div class="article-menu">
#
# 					<div class="trigger">&#x22ef;</div>
# 					<div class="dropdown">
# 						<div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E5%95%8F%E5%8D%A6%5D&#43;%E8%87%AA%E5%B7%B1%E7%BF%BB%E6%96%B0%E9%9B%BB%E6%B1%A0%E5%BE%88%E6%AF%92%E5%97%8E%EF%BC%9F">搜尋同標題文章</a></div>
#
# 						<div class="item"><a href="/bbs/Gossiping/search?q=author%3Anekokick">搜尋看板內 nekokick 的文章</a></div>
#
# 					</div>
#
# 				</div>
# 				<div class="date"> 3/09</div>
# 				<div class="mark"></div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"></div>
# 			<div class="title">
#
# 				<a href="/bbs/Gossiping/M.1646815708.A.DF7.html">[問卦]  正在吃二良烤饅頭有掛嗎</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="author">chouvincent</div>
# 				<div class="article-menu">
#
# 					<div class="trigger">&#x22ef;</div>
# 					<div class="dropdown">
# 						<div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E5%95%8F%E5%8D%A6%5D&#43;&#43;%E6%AD%A3%E5%9C%A8%E5%90%83%E4%BA%8C%E8%89%AF%E7%83%A4%E9%A5%85%E9%A0%AD%E6%9C%89%E6%8E%9B%E5%97%8E">搜尋同標題文章</a></div>
#
# 						<div class="item"><a href="/bbs/Gossiping/search?q=author%3Achouvincent">搜尋看板內 chouvincent 的文章</a></div>
#
# 					</div>
#
# 				</div>
# 				<div class="date"> 3/09</div>
# 				<div class="mark"></div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"><span class="hl f2">3</span></div>
# 			<div class="title">
#
# 				<a href="/bbs/Gossiping/M.1646815723.A.969.html">[新聞]我們靠自己苦撐13天了! 澤連斯基怒問西方</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="author">Aliensoul</div>
# 				<div class="article-menu">
#
# 					<div class="trigger">&#x22ef;</div>
# 					<div class="dropdown">
# 						<div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E6%96%B0%E8%81%9E%5D%E6%88%91%E5%80%91%E9%9D%A0%E8%87%AA%E5%B7%B1%E8%8B%A6%E6%92%9013%E5%A4%A9%E4%BA%86%21&#43;%E6%BE%A4%E9%80%A3%E6%96%AF%E5%9F%BA%E6%80%92%E5%95%8F%E8%A5%BF%E6%96%B9">搜尋同標題文章</a></div>
#
# 						<div class="item"><a href="/bbs/Gossiping/search?q=author%3AAliensoul">搜尋看板內 Aliensoul 的文章</a></div>
#
# 					</div>
#
# 				</div>
# 				<div class="date"> 3/09</div>
# 				<div class="mark"></div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"></div>
# 			<div class="title">
#
# 				<a href="/bbs/Gossiping/M.1646815796.A.3BD.html">[問卦] 醬油膏真的不噁嗎??</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="author">a187</div>
# 				<div class="article-menu">
#
# 					<div class="trigger">&#x22ef;</div>
# 					<div class="dropdown">
# 						<div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E5%95%8F%E5%8D%A6%5D&#43;%E9%86%AC%E6%B2%B9%E8%86%8F%E7%9C%9F%E7%9A%84%E4%B8%8D%E5%99%81%E5%97%8E%3F%3F">搜尋同標題文章</a></div>
#
# 						<div class="item"><a href="/bbs/Gossiping/search?q=author%3Aa187">搜尋看板內 a187 的文章</a></div>
#
# 					</div>
#
# 				</div>
# 				<div class="date"> 3/09</div>
# 				<div class="mark"></div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"></div>
# 			<div class="title">
#
# 				<a href="/bbs/Gossiping/M.1646815803.A.11B.html">[問卦] 工作做不完同事沒事卻叫我加班他幫我?</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="author">sivhd</div>
# 				<div class="article-menu">
#
# 					<div class="trigger">&#x22ef;</div>
# 					<div class="dropdown">
# 						<div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E5%95%8F%E5%8D%A6%5
(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
#
#   ga('create', 'UA-32365737-1', {
#     cookieDomain: 'ptt.cc',
#     legacyCookieDomain: 'ptt.cc'
#   });
#   ga('send', 'pageview');
# </script>
#
#
#
# <script src="//ajax.googleapis.com/ajax/libs/jquery/2.1.1/jquery.min.js"></script>
# <script src="//images.ptt.cc/bbs/v2.27/bbs.js"></script>
#
#     </body>
# </html>

# %%
from requests_html import HTML

def parse_article_entries(doc):
    html = HTML(html=doc)
    post_entries = html.find('div.r-ent')
    return post_entries

url = 'https://www.ptt.cc/bbs/movie/index.html'
resp = fetch(url)  # step-1
post_entries = parse_article_entries(resp.text)  # step-2

print(post_entries)  # result of setp-2
# Out:
# [<Element 'div' class=('r-ent',)>, <Element 'div' class=('r-ent',)>, <Element 'div' class=('r-ent',)>, <Element 'div' class=('r-ent',)>, <Element 'div' class=('r-ent',)>, <Element 'div' class=('r-ent',)>, <Element 'div' class=('r-ent',)>, <Element 'div' class=('r-ent',)>, <Element 'div' class=('r-ent',)>, <Element 'div' class=('r-ent',)>, <Element 'div' class=('r-ent',)>]

# %%
def parse_article_meta(entry):
    '''
    每筆資料都存在 dict() 類型中：key-value paird data
    '''
    return {
        'title': entry.find('div.title', first=True).text,
        'push': entry.find('div.nrec', first=True).text,
        'date': entry.find('div.date', first=True).text,
        'author': entry.find('div.author', first=True).text,
        'link': entry.find('div.title > a', first=True).attrs['href'],
    }

url = 'https://www.ptt.cc/bbs/movie/index.html'
resp = fetch(url)  # step-1
post_entries = parse_article_entries(resp.text)  # step-2

for entry in post_entries:
    meta = parse_article_meta(entry)
    print(meta)  # result of setp-3
    # pretty_print(meta['push'], meta['title'], meta['date'], meta['author'])  # for below results
# Out:
# {'title': '[情報] 2022 視覺特效協會 得獎名單', 'push': '', 'date': '3/09', 'author': 'qpr322', 'link': '/bbs/movie/M.1646807715.A.52C.html'}
# {'title': '[討論]《穿著prada的惡魔》', 'push': '7', 'date': '3/09', 'author': 'jrchyan', 'link': '/bbs/movie/M.1646809659.A.8DC.html'}
# {'title': '[問片] 一部老片', 'push': '', 'date': '3/09', 'author': 'krit1009', 'link': '/bbs/movie/M.1646810685.A.B00.html'}
# {'title': '[好雷] 時代革命：壓迫感極重，因為無比真實', 'push': '', 'date': '3/09', 'author': 'GeneralRamir', 'link': '/bbs/movie/M.1646815827.A.9A0.html'}
# {'title': '[情報] 2022 美國作曲家及作詞家協會獎 得獎名單', 'push': '', 'date': '3/09', 'author': 'lgng66133', 'link': '/bbs/movie/M.1646815928.A.82C.html'}
# {'title': '[問片] 一部跟裁縫師有關的片子?', 'push': '2', 'date': '3/09', 'author': 'goetz', 'link': '/bbs/movie/M.1646816332.A.CB4.html'}
# {'title': '[負雷] 這蝙蝠俠很不行', 'push': '1', 'date': '3/09', 'author': 'aher2600', 'link': '/bbs/movie/M.1646816817.A.F34.html'}
# {'title': '[公告] 電影板板規 2021/9/4', 'push': '', 'date': '9/04', 'author': 'ckshchen', 'link': '/bbs/movie/M.1630756788.A.1FE.html'}
# {'title': '[情報] 2022 奧斯卡金像獎 入圍名單', 'push': '爆', 'date': '2/08', 'author': 'qpr322', 'link': '/bbs/movie/M.1644327722.A.4C7.html'}
# {'title': '[情報] 2022 奧斯卡金像獎 入圍統計&觀看管道', 'push': '52', 'date': '2/08', 'author': 'lgng66133', 'link': '/bbs/movie/M.1644330059.A.03A.html'}
# {'title': '[公告] movie板 樂透! 奧斯卡獎最佳女主角', 'push': '', 'date': '2/09', 'author': 'lgng66133', 'link': '/bbs/movie/M.1644400612.A.392.html'}
# {'title': '[公告] 2022北美獎季影帝影后猜猜樂活動 至2/25', 'push': '20', 'date': '2/14', 'author': 'lgng66133', 'link': '/bbs/movie/M.1644815102.A.782.html'}

# %%
id = get controll button

metas = []
pages = 100
for i in range(id - pages, id):
    meta = parse_article_entries()
    metas.extend(meta)

return metas
